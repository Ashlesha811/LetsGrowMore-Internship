# %% [markdown]
# # LETSGROWMORE
# ## TASK 4
# ### Image to Pencil sketch                    --- Ashlesha Baral

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline

# %%
image = cv2.imread("cat.jpg")

# %%
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
grey_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow("New cat", gray_image)
cv2.waitKey(0)
# Out:
# -1

# %%
plt.imshow(grey_image)

# %%
inverted_image = 255 - gray_image
cv2.imshow("Inverted", inverted_image)
cv2.waitKey()
# Out:
# -1

# %%
plt.imshow(inverted_image)

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
blurred
# Out:
# array([[129, 129, 128, ..., 203, 202, 202],
#        [130, 130, 129, ..., 203, 202, 202],
#        [132, 131, 130, ..., 203, 203, 202],
#        ...,
#        [102, 102, 100, ..., 183, 184, 184],
#        [104, 104, 102, ..., 184, 185, 185],
#        [105, 104, 103, ..., 184, 185, 185]], dtype=uint8)

# %%
plt.imshow(blurred)

# %%
inverted_blur = 255 - blurred
sketch = cv2.divide(gray_image,inverted_blur,scale = 256.0)
cv2.imshow("Pencil Sketch", sketch)
cv2.waitKey(0)
# Out:
# -1

# %%
plt.imshow(sketch)

# %%
display(Image.fromarray(img_rgb))
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x18107740670>
# <PIL.Image.Image image mode=L size=300x168 at 0x181076968B0>
